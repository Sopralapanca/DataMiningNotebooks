# %% [markdown]
# # Apriori algorithm

# %% [markdown]
# #### we used the FIM package. You can find it here for Ananconda installation https://anaconda.org/conda-forge/pyfim.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fim import apriori

# %% [markdown]
# #### Pattern mining on relational data

# %%
dataset = pd.read_csv("./datasets/small_transactions.csv", skipinitialspace=True, sep=',', nrows=2000)
dataset.head()
# Out:
#     SCONTRINO_ID  COD_MKT_ID
# 0  2558064013053        1580
# 1  2558064013053        1661
# 2  2558064013053        2068
# 3  2558064013053        2556
# 4  2558064013053        2650

# %% [markdown]
# ##### This is a relational representation: each row of the dataframe has a basket ID and one product bought. For our analysis, we need the transactions: the list of product bought for each basket.

# %%
transactions = dataset.groupby('SCONTRINO_ID')['COD_MKT_ID'].apply(list)
transactions.head()
# Out:
# SCONTRINO_ID
# 2558064013053                 [1580, 1661, 2068, 2556, 2650, 4225]
# 2558064013054    [437, 1278, 1614, 2089, 2243, 2245, 2443, 2551...
# 2558064013055                         [151, 595, 2650, 4600, 4872]
# 2558064013056             [142, 437, 2499, 2515, 3458, 3675, 4044]
# 2558064013057                                          [437, 3087]
# Name: COD_MKT_ID, dtype: object

# %%
baskets = transactions.values

# %%
baskets[0:5]
# Out:
# array([list([1580, 1661, 2068, 2556, 2650, 4225]),
#        list([437, 1278, 1614, 2089, 2243, 2245, 2443, 2551, 3448, 6172]),
#        list([151, 595, 2650, 4600, 4872]),
#        list([142, 437, 2499, 2515, 3458, 3675, 4044]), list([437, 3087])],
#       dtype=object)

# %% [markdown]
# #### We can now run the apriori algorithm, implemented in fim. To know the options available:

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
#             r     rules      association rules
#     supp    minimum support of an item set         (default: 10)
#             (positive: percentage, negative: absolute number)
#     conf    minimum confidence of an assoc. rule   (default: 80%)
#     zmin    minimum number of items per item set   (default: 1)
#     zmax    maximum number of items per item set   (default: no limit)
#     report  values to report with an item set      (default: a)
#             a     absolute item set support (number of transactions)
#             s     relative item set support as a fraction
#             S     relative item set support as a percentage
#             e     value of item set evaluation measure
#             E     value of item set evaluation measure as a percentage
#             (     combine values in a tuple (must be first character)
#             [     combine values in a list  (must be first character)
#             #     pattern spectrum as a dictionary  (no patterns)
#             =     pattern spectrum as a list        (no patterns)
#             |     pattern spectrum as three columns (no patterns)
#             for target 'r' (association rules) also available:
#             b     absolute body set  support (number of transactions)
#             x     relative body set  support as a fraction
#             X     relative body set  support as a percentage
#             h     absolute head item support (number of transactions)
#             y     relative head item support as a fraction
#             Y     relative head item support as a percentage
#             c     rule confidence as a fraction
#             C     rule confidence as a percentage
#             l     lift value of a rule (confidence/prior)
#             L     lift value of a rule as a percentage
#             Q     support of the empty set (total number of transactions)
#     eval    measure for item set evaluation        (default: x)
#             x     none       no measure / zero (default)
#             b     ldratio    binary logarithm of support quotient       (+)
#             c     conf       rule confidence                            (+)
#             d     confdiff   absolute confidence difference to prior    (+)
#             l     lift       lift value (confidence divided by prior)   (+)
#             a     liftdiff   absolute difference of lift value to 1     (+)
#             q     liftquot   difference of lift quotient to 1           (+)
#             v     cvct       conviction (inverse lift for negated head) (+)
#             e     cvctdiff   absolute difference of conviction to 1     (+)
#             r     cvctquot   difference of conviction quotient to 1     (+)
#             k     cprob      conditional probability ratio              (+)
#             j     import     importance (binary log. of prob. ratio)    (+)
#             z     cert       certainty factor (relative conf. change)   (+)
#             n     chi2       normalized chi^2 measure                   (+)
#             p     chi2pval   p-value from (unnormalized) chi^2 measure  (-)
#             y     yates      normalized chi^2 with Yates' correction    (+)
#             t     yatespval  p-value from Yates-corrected chi^2 measure (-)
#             i     info       information difference to prior            (+)
#             g     infopval   p-value from G statistic/info. difference  (-)
#             f     fetprob    Fisher's exact test (table probability)    (-)
#             h     fetchi2    Fisher's exact test (chi^2 measure)        (-)
#             m     fetinfo    Fisher's exact test (mutual information)   (-)
#             s     fetsupp    Fisher's exact test (support)              (-)
#             Measures marked with (+) must meet or exceed the threshold,
#             measures marked with (-) must not exceed the threshold
#             in order for the item set to be reported.
#     agg     evaluation measure aggregation mode    (default: x)
#             x     none       no aggregation (use first value)
#             m     min        minimum of individual measure values
#             n     max        maximum of individual measure values
#             a     avg        average of individual measure values
#     thresh  threshold for evaluation measure       (default: 10%)
#     prune   min. size for evaluation filtering     (default: no pruning)
#             = 0   backward filtering       (no subset check)
#             < 0   weak   forward filtering (one subset  must qualify)
#             > 0   strong forward filtering (all subsets must qualify)
#     algo    algorithm variant to use               (default: a)
#             b     basic      standard algorithm (only choice)
#     mode    operation mode indicators/flags        (default: None)
#             x     do not use perfect extension pruning
#             t/T   do not organize transactions as a prefix tree
#             y     a-posteriori pruning of infrequent item sets
#             z     invalidate evaluation below expected support
#             o     use original rule support definition (body & head)
#     border  support border for filtering item sets (default: None)
#             Must be a list or tuple of (absolute) minimum support values
#             per item set size (by which the list/tuple is indexed).
#     appear  dictionary mapping items to item appearance indicators,
#             with the key None referring to the default item appearance.
#             (If None does not occur as a key or no dictionary is given,
#             the default item appearance indicator is 'both'.)
#             This parameter is only used if the target type is rules.
#             * item may not appear anywhere in a rule:
#               '-', 'n', 'none', 'neither', 'ignore'
#             * item may appear only in rule body/antecedent:
#               'i', 'in', 'inp', 'input', 'b', 'body',
#               'a', 'ante', 'antecedent'
#             * item may appear only in rule head/consequent:
#               'o', 'out',      'output', 'h', 'head',
#               'c', 'cons', 'consequent'
#             * item may appear anywhere in a rule:
#               'io', 'i&o', 'inout', 'in&out', 'bh', 'b&h', 'both'
#     returns if report is not in ['#','=','|']:
#               if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.
#               if the target is a type of item sets:
#                 a list of patterns (i.e. tuples with one or more elements),
#                 each consisting of a tuple with a found frequent item set
#                 and the values selected by the parameter 'report', which
#                 may be combined into a tuple or list if report[0] is '('
#                 or '[', respectively
#             if report in ['#','=','|']:
#               a pattern spectrum as a dictionary mapping pattern sizes
#               to the corresponding occurrence support ranges, as a list
#               of triplets (size, min. support, max. support) or as three
#               columns for sizes and minimum and maximum support values

# %% [markdown]
# #### First, we want to extract the itemsets: we do it setting target=a

# %%
itemsets = apriori(baskets, supp=1, zmin=2, zmax=5, target='a')

# %% [markdown]
# #### We can now see the itemsets obtained and their support

# %%
print('Number of itemsets:', len(itemsets))
# Out:
# Number of itemsets: 392

# %%
itemsets[20:35]
# Out:
# [((4461, 920), 3),
#  ((142, 393), 3),
#  ((1258, 2650), 3),
#  ((2518, 2499), 3),
#  ((2518, 920), 3),
#  ((599, 597), 3),
#  ((2550, 2650), 3),
#  ((4136, 6172), 3),
#  ((3074, 437), 3),
#  ((1658, 445), 4),
#  ((1658, 445, 2650), 3),
#  ((1658, 2650), 3),
#  ((1429, 1428), 4),
#  ((207, 2650), 3),
#  ((563, 2194), 3)]

# %% [markdown]
# #### With apriori we can also extract the rules, by setting target=r. Remeber that in this case we need to set a support value as well as a confidence one

# %%
rules = apriori(baskets, supp=1, zmin=2, target='r', conf=60, report='ascl')

# %%
print('Number of rule:', len(rules))
# Out:
# Number of rule: 1096

# %%
#visualization of one rule
rules[100]
# Out:
# (2548,
#  (2193, 2499, 920),
#  2,
#  0.00881057268722467,
#  0.6666666666666666,
#  75.66666666666667)

# %%
count = 0
for r in rules:
    if r[5] > 2 and r[4] > 0.7:
        print(r)
        count += 1
        if count == 10:
            break
# Out:
# (2443, (3086,), 3, 0.013215859030837005, 1.0, 9.869565217391305)
# (2050, (441,), 3, 0.013215859030837005, 0.75, 13.096153846153847)
# (2650, (441,), 3, 0.013215859030837005, 0.75, 2.541044776119403)
# (2243, (1278,), 4, 0.01762114537444934, 1.0, 14.1875)
# (437, (4805,), 3, 0.013215859030837005, 1.0, 9.458333333333334)
# (2650, (396,), 3, 0.013215859030837005, 1.0, 3.388059701492537)
# (2650, (4163,), 3, 0.013215859030837005, 1.0, 3.388059701492537)
# (2729, (385,), 3, 0.013215859030837005, 0.75, 8.5125)
# (2650, (4182, 445), 3, 0.013215859030837005, 1.0, 3.388059701492537)
# (445, (4182, 2650), 3, 0.013215859030837005, 1.0, 5.27906976744186)

# %% [markdown]
# #### Given a rule, we can print the baksets that contain the premises of the rule

# %%
rules[9][1]
# Out:
# (588,)

# %%
rules[9][0]
# Out:
# 597

# %%
for b in baskets:
    if set(rules[9][1]) < set(b) and rules[9][0] in set(b):
            print(b)
# Out:
# [505, 566, 588, 597, 607, 629, 632, 2058, 2727, 2729, 2731, 4003, 4126, 4228]
# [588, 597, 598, 615, 620, 622, 623, 624, 1508, 4801]

# %% [markdown]
# # Pattern mining on tabular data

# %%
df = pd.read_csv("./datasets/titanic.csv", skipinitialspace=True, sep=',')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Some pre-processing steps

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape

#drop cabin
# Out:
# (891, 12)

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

df['Age'] = df['Age'].groupby([df['Sex'], df['Pclass']]).apply(
    lambda x: x.fillna(x.median()))
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

df.isnull().sum()
# Out:
# C:\Users\giaco\AppData\Local\Temp\ipykernel_6736\469501098.py:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df['Age'] = df['Age'].groupby([df['Sex'], df['Pclass']]).apply(
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
column2drop = ['PassengerId', 'Name', 'Cabin', 'SibSp', 
               'Parch', 'Ticket']
df.drop(column2drop, axis=1, inplace=True)

df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  FamilySize
# 0         0       3    male  22.0   7.2500        S           2
# 1         1       1  female  38.0  71.2833        C           2
# 2         1       3  female  26.0   7.9250        S           1
# 3         1       1  female  35.0  53.1000        S           2
# 4         0       3    male  35.0   8.0500        S           1

# %%
df['AgeBin'] = pd.cut(df['Age'].astype(int), 10, right=False)
df['FareBin'] = pd.cut(df['Fare'].astype(int), 10, right=False)

df.drop(['Age', 'Fare'], axis=1, inplace=True)

df.head()
# Out:
#    Survived  Pclass     Sex Embarked  FamilySize        AgeBin        FareBin
# 0         0       3    male        S           2  [16.0, 24.0)    [0.0, 51.2)
# 1         1       1  female        C           2  [32.0, 40.0)  [51.2, 102.4)
# 2         1       3  female        S           1  [24.0, 32.0)    [0.0, 51.2)
# 3         1       1  female        S           2  [32.0, 40.0)  [51.2, 102.4)
# 4         0       3    male        S           1  [32.0, 40.0)    [0.0, 51.2)

# %%
df['Survived'] = df['Survived'].map(
    {0: 'Not Survived', 1: 'Survived'}).astype(str)
df['Pclass'] = df['Pclass'].map(
    {1: '1st', 2: '2nd', 3: '3rd'}).astype(str)

df['FamilySize'] = df['FamilySize'].astype(str) + '_Family'
df['AgeBin'] = df['AgeBin'].astype(str) + '_Age'
df['FareBin'] = df['FareBin'].astype(str) + '_Fare'

df.head()
# Out:
#        Survived Pclass     Sex Embarked FamilySize            AgeBin  \
# 0  Not Survived    3rd    male        S   2_Family  [16.0, 24.0)_Age
# 1      Survived    1st  female        C   2_Family  [32.0, 40.0)_Age
# 2      Survived    3rd  female        S   1_Family  [24.0, 32.0)_Age
# 3      Survived    1st  female        S   2_Family  [32.0, 40.0)_Age
# 4  Not Survived    3rd    male        S   1_Family  [32.0, 40.0)_Age
#
#               FareBin
# 0    [0.0, 51.2)_Fare
# 1  [51.2, 102.4)_Fare
# 2    [0.0, 51.2)_Fare
# 3  [51.2, 102.4)_Fare
# 4    [0.0, 51.2)_Fare

# %%
baskets = df.values.tolist()

# %%
baskets
# Out:
# [['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '5_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '6_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[64.0, 72.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '8_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '8_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '6_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '4_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '6_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '5_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '11_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'Q',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[460.8, 512.512)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'female',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'Q',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[153.6, 204.8)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '6_Family',
#   '[24.0, 32.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '8_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'Q',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '4_Family',
#   '[8.0, 16.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '6_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '6_Family',
#   '[64.0, 72.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
# ...
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[460.8, 512.512)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[64.0, 72.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '4_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '5_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '4_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '11_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '4_Family',
#   '[8.0, 16.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '2_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'C',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[72.0, 80.08)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[153.6, 204.8)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '4_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '11_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'Q',
#   '6_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '4_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare']]

# %%
baskets[0] # description of a person
# Out:
# ['Not Survived',
#  '3rd',
#  'male',
#  'S',
#  '2_Family',
#  '[16.0, 24.0)_Age',
#  '[0.0, 51.2)_Fare']

# %% [markdown]
# #### We apply apriori on the baskets

# %%
itemsets = apriori(baskets, supp=1, zmin=2, target='a')

# %%
rules = apriori(baskets, supp=2, conf=2, target='r')

# %%
rules
# Out:
# [('[72.0, 80.08)_Age',
#   ('1st', 'Survived', '1_Family', 'male', '[0.0, 51.2)_Fare'),
#   1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '1_Family', 'male'), 1),
#  ('[72.0, 80.08)_Age',
#   ('1st', 'Survived', '1_Family', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '1_Family', 'S'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '1_Family', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'male', 'S'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'male'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age',
#   ('1st', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('[72.0, 80.08)_Age', ('1st', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age',
#   ('Survived', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('[72.0, 80.08)_Age', ('Survived', '1_Family', 'male', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', '1st', 'Survived'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', '1st', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', '1st'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'female', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'female'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'Survived', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'Survived'), 1),
#  ('[153.6, 204.8)_Fare', ('3_Family', '1st', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', '1st'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', '[24.0, 32.0)_Age'), 1),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', '[24.0, 32.0)_Age', 'Survived'), 1),
#  ('[153.6, 204.8)_Fare', ('1st', '[24.0, 32.0)_Age'), 1),
#  ('[153.6, 204.8)_Fare', ('1st', 'female', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'female', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'female', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'female'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '2_Family', '1st'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '2_Family', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '2_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'C', '1st'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'C'), 3),
#  ('[460.8, 512.512)_Fare',
#   ('[32.0, 40.0)_Age', '1st', 'female', 'Survived'),
#   1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', 'female'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'female', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'female'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'Survived', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age',), 3),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'C', '1st', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'C', '1st'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'C', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'C', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', '1st', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'Survived', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'female', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'female'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('C', '1st', '1_Family', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('C', '1st'), 3),
#  ('[460.8, 512.512)_Fare', ('C', 'female', 'Survived', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('C', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('C', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', 'Survived', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('C', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('C', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('1st', 'female', 'Survived', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('1st', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived', '1_Family', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived'), 3),
#  ('8_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('8_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', '3rd'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'S'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age',), 3),
#  ('8_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', '3rd'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', 'male'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', 'S'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[0.0, 8.0)_Age',), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', 'female', 'S'), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', 'female', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', 'female'), 1),
#  ('8_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'S'), 1),
#  ('8_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived'), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', '3rd', 'S'), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('[40.0, 48.0)_Age', '3rd'), 1),
#  ('8_Family',
#   ('[40.0, 48.0)_Age', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family',
#   ('[16.0, 24.0)_Age',
#    'female',
#    '3rd',
#    'Not Survived',
#    'S',
#    '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', 'S'), 1),
#  ('8_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived'), 1),
#  ('8_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'S'), 1),
#  ('8_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S'), 1),
#  ('8_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Not Survived', '[0.0, 51.2)_Fare'),
#   1),
#  ('8_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived'), 1),
#  ('8_Family', ('[16.0, 24.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('8_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', '3rd', 'Not Survived', 'S'), 2),
#  ('8_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', '3rd', 'Not Survived'), 2),
#  ('8_Family', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', '3rd', 'S'), 2),
#  ('8_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', 'Not Survived', 'S'), 2),
#  ('8_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', 'Not Survived'), 2),
#  ('8_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('8_Family', ('3rd', 'Not Survived', 'S'), 6),
#  ('[256.0, 307.2)_Fare', ('6_Family', 'Not Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('6_Family',), 4),
#  ('[256.0, 307.2)_Fare', ('C', '[16.0, 24.0)_Age', 'female'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '[16.0, 24.0)_Age', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '[16.0, 24.0)_Age'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st', 'female', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st', 'female'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st'), 2),
#  ('[256.0, 307.2)_Fare', ('C', 'female', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', 'female'), 2),
#  ('[256.0, 307.2)_Fare', ('C', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st', 'female'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st'), 4),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'female', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'female'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'Survived', 'S'), 1),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('1st', '[24.0, 32.0)_Age', 'Survived'), 1),
#  ('[256.0, 307.2)_Fare', ('1st', '[24.0, 32.0)_Age'), 1),
#  ('[256.0, 307.2)_Fare', ('1st', 'female', 'Survived', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'female', 'Survived'), 4),
#  ('[256.0, 307.2)_Fare', ('1st', 'female', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'female'), 4),
#  ('[256.0, 307.2)_Fare', ('1st', 'Survived', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Survived'), 4),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived', 'male', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived', 'male'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'male', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'S'), 4),
#  ('[256.0, 307.2)_Fare', ('1st',), 6),
#  ('[256.0, 307.2)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('[256.0, 307.2)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived'), 1),
#  ('11_Family', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age', 'male'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age', 'S'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'female', 'S'), 3),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'female'), 3),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived', 'male', 'S'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived', 'male'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived', 'S'), 7),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived'), 7),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'male', 'S'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'male'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'S'), 7),
#  ('11_Family', ('[51.2, 102.4)_Fare',), 7),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', '3rd', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'S'), 3),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived', 'male', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived', 'male'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'male', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'male'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'Not Survived', 'male', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'Not Survived', 'male'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'Not Survived', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'male', 'S'), 4),
#  ('11_Family', ('female', '3rd', 'Not Survived', 'S'), 3),
#  ('11_Family', ('female', '3rd', 'Not Survived'), 3),
#  ('11_Family', ('female', '3rd', 'S'), 3),
#  ('11_Family', ('female', '3rd'), 3),
#  ('11_Family', ('female', 'Not Survived', 'S'), 3),
#  ('11_Family', ('female', 'Not Survived'), 3),
#  ('11_Family', ('3rd', 'Not Survived', 'S'), 7),
#  ('[204.8, 256.0)_Fare', ('[8.0, 16.0)_Age', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('[8.0, 16.0)_Age', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[8.0, 16.0)_Age',), 1),
#  ('[204.8, 256.0)_Fare', ('[48.0, 56.0)_Age', '1st', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[48.0, 56.0)_Age', '1st'), 1),
#  ('[204.8, 256.0)_Fare', ('[48.0, 56.0)_Age', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('[48.0, 56.0)_Age', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[48.0, 56.0)_Age',), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'Not Survived', 'male', 'S'),
#   1),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'Not Survived', 'male'),
#   2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'Not Survived', 'S'),
#   1),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'Not Survived'),
#   2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'male', 'S'),
#   1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', '1_Family', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', '1_Family', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', 'Not Survived', 'male', 'S'),
#   1),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', 'Not Survived', 'male'),
#   2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'Not Survived', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'male', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st'), 4),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'female', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'female'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Survived', '1_Family'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Survived', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1_Family', 'Not Survived', 'male', 'S'),
#   1),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1_Family', 'Not Survived', 'male'),
#   2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1_Family', 'Not Survived', 'S'),
#   1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1_Family', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1_Family', 'male', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1_Family', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1_Family', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Not Survived', 'male', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Not Survived', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age',), 4),
#  ('[204.8, 256.0)_Fare', ('3_Family', 'C'), 1),
#  ('[204.8, 256.0)_Fare', ('3_Family', '1st'), 1),
#  ('[204.8, 256.0)_Fare', ('3_Family', '[24.0, 32.0)_Age'), 1),
#  ('[204.8, 256.0)_Fare', ('3_Family', 'Not Survived', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('3_Family', 'Not Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', 'C', '1st'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', 'C'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', '1st', 'female', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', '1st', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', '1st', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', '1st', '1_Family'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', '1st'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', 'female', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', 'female', '1_Family'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('[32.0, 40.0)_Age', 'Survived', '1_Family'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st', 'female', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st', 'female'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st'), 3),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'female', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'female'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C'), 3),
#  ('[204.8, 256.0)_Fare',
#   ('2_Family', '[16.0, 24.0)_Age', 'female', 'Survived'),
#   1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '[16.0, 24.0)_Age', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '[16.0, 24.0)_Age', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '[16.0, 24.0)_Age'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'Not Survived', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'Not Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st'), 5),
#  ('[204.8, 256.0)_Fare',
#   ('2_Family', '[24.0, 32.0)_Age', 'Not Survived', 'male'),
#   1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '[24.0, 32.0)_Age', 'Not Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '[24.0, 32.0)_Age', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', '[24.0, 32.0)_Age'), 1),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family',), 5),
#  ('[204.8, 256.0)_Fare', ('C', '[16.0, 24.0)_Age', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('C', '[16.0, 24.0)_Age', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('C', '[16.0, 24.0)_Age'), 1),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'female', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Survived', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1st', '1_Family', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('C', '1st', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Not Survived', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Not Survived'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st'), 7),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age', 'Not Survived', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'female', 'Survived', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', 'female', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('C', 'Survived', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1_Family', 'Not Survived', 'male'), 1),
#  ('[204.8, 256.0)_Fare', ('C', '1_Family', 'Not Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('C', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('C', 'Not Survived', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C', 'Not Survived'), 3),
#  ('[204.8, 256.0)_Fare', ('C', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C',), 7),
#  ('[204.8, 256.0)_Fare', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[16.0, 24.0)_Age', '1st', 'female'), 1),
#  ('[204.8, 256.0)_Fare', ('[16.0, 24.0)_Age', '1st', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[16.0, 24.0)_Age', '1st'), 1),
#  ('[204.8, 256.0)_Fare', ('1st', '[24.0, 32.0)_Age', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('1st', '[24.0, 32.0)_Age', '1_Family'), 1),
#  ('[204.8, 256.0)_Fare', ('1st', '[24.0, 32.0)_Age', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('1st', '[24.0, 32.0)_Age'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'Survived', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'Survived', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'Survived'), 7),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female'), 7),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived', '1_Family', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived'), 7),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family', 'Not Survived', 'male', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family', 'Not Survived', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family', 'Not Survived', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family'), 5),
#  ('[204.8, 256.0)_Fare', ('1st', 'Not Survived', 'male'), 4),
#  ('[204.8, 256.0)_Fare', ('1st', 'Not Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('1st', 'male'), 4),
#  ('[204.8, 256.0)_Fare', ('1st', 'S'), 4),
#  ('[204.8, 256.0)_Fare', ('1st',), 11),
#  ('[204.8, 256.0)_Fare',
#   ('[24.0, 32.0)_Age', 'female', 'Survived', '1_Family'),
#   1),
#  ('[204.8, 256.0)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived'), 1),
#  ('[204.8, 256.0)_Fare', ('[24.0, 32.0)_Age', 'female', '1_Family', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('[24.0, 32.0)_Age', 'female', '1_Family'), 1),
#  ('[204.8, 256.0)_Fare', ('[24.0, 32.0)_Age', 'Survived', '1_Family', 'S'), 1),
#  ('[204.8, 256.0)_Fare', ('female', 'Survived', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('female', 'Survived', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('female', 'Survived'), 7),
#  ('[204.8, 256.0)_Fare', ('female', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('female',), 7),
#  ('[204.8, 256.0)_Fare', ('Survived',), 7),
#  ('[64.0, 72.0)_Age', ('6_Family', 'Not Survived'), 1),
#  ('[64.0, 72.0)_Age', ('6_Family',), 1),
#  ('[64.0, 72.0)_Age',
#   ('Q', '3rd', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '3rd', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q',), 2),
#  ('[64.0, 72.0)_Age', ('3_Family', '1st'), 1),
#  ('[64.0, 72.0)_Age', ('3_Family', 'Not Survived', 'male', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('3_Family', 'Not Survived', 'male'), 1),
#  ('[64.0, 72.0)_Age', ('3_Family', 'Not Survived', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('3_Family', 'Not Survived'), 1),
#  ('[64.0, 72.0)_Age', ('3_Family', 'male', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', 'C', '1st'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', 'C'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', '1st', 'male'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', 'male'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'C', '1st'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'C'), 1),
#  ('[64.0, 72.0)_Age',
#   ('[51.2, 102.4)_Fare', '1st', 'Not Survived', 'male'),
#   2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'male', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'Not Survived', 'male', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'Not Survived', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'male', 'S'), 1),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('2_Family', 'C', '1st'), 1),
#  ('[64.0, 72.0)_Age', ('2_Family', 'C', 'male'), 1),
#  ('[64.0, 72.0)_Age', ('2_Family', '1st', 'Not Survived', 'male'), 1),
#  ('[64.0, 72.0)_Age', ('2_Family', '1st', 'Not Survived'), 1),
#  ('[64.0, 72.0)_Age', ('2_Family', '1st', 'male'), 1),
#  ('[64.0, 72.0)_Age', ('C', '1st', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', '1_Family', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', '1_Family'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'Not Survived', 'male'), 3),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'Not Survived'), 3),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'male'), 3),
#  ('[64.0, 72.0)_Age', ('C', '1st', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st'), 3),
#  ('[64.0, 72.0)_Age',
#   ('C', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('C', '1_Family', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('C', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('C', '1_Family', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1_Family', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1_Family', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1_Family'), 2),
#  ('[64.0, 72.0)_Age', ('C', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', 'Not Survived', 'male'), 3),
#  ('[64.0, 72.0)_Age', ('C', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', 'Not Survived'), 3),
#  ('[64.0, 72.0)_Age', ('C', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', 'male'), 3),
#  ('[64.0, 72.0)_Age',
#   ('2nd', '1_Family', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'Not Survived', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('2nd', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('2nd', '1_Family', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'Not Survived', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('2nd', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', '1_Family', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('2nd', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived', 'S'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'male', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('2nd', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived', 'male'), 4),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'male'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'S'), 2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family'), 4),
#  ('[64.0, 72.0)_Age',
#   ('1st', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'male', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'male'), 7),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived'), 7),
#  ('[64.0, 72.0)_Age', ('1st', 'male', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('1st', 'male', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'male'), 7),
#  ('[64.0, 72.0)_Age', ('1st', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('1st', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st',), 7),
#  ('[64.0, 72.0)_Age',
#   ('1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'Not Survived', 'male'), 8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'Not Survived', '[0.0, 51.2)_Fare'), 8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'Not Survived'), 8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'male', '[0.0, 51.2)_Fare'), 8),
#  ('[64.0, 72.0)_Age', ('Not Survived', 'male'), 11),
#  ('[64.0, 72.0)_Age', ('Not Survived',), 11),
#  ('7_Family', ('[8.0, 16.0)_Age', 'female'), 2),
#  ('7_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('7_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', '3rd'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'S'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age',), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female', 'Survived', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female', 'Survived'), 1),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female', 'S'), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female'), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived', 'S'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', 'S'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age',), 5),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', 'Survived'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', 'S'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', 'Survived', 'S'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', 'Survived', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'male', 'S'), 1),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   1),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'male'), 1),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'S'), 2),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'male', 'S'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'male'), 1),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'S'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd'), 3),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'Not Survived', 'S'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'Not Survived'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', 'S'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age',), 3),
#  ('7_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Survived', '3rd', '[0.0, 51.2)_Fare'),
#   1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'female', 'Survived', '3rd'), 1),
#  ('7_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('7_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'S'), 1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'Survived', '3rd'), 1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('[16.0, 24.0)_Age', 'Survived', 'S'), 1),
#  ('7_Family', ('female', 'Survived', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('female', 'Survived', '3rd', 'S'), 3),
#  ('7_Family', ('female', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('female', 'Survived', '3rd'), 3),
#  ('7_Family', ('female', 'Survived', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('female', 'Survived', 'S'), 3),
#  ('7_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', '3rd', 'Not Survived', 'S'), 5),
#  ('7_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', '3rd', 'Not Survived'), 5),
#  ('7_Family', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female', '3rd', 'S'), 8),
#  ('7_Family', ('female', '3rd', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female', '3rd'), 8),
#  ('7_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', 'Not Survived', 'S'), 5),
#  ('7_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', 'Not Survived'), 5),
#  ('7_Family', ('female', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female', 'S'), 8),
#  ('7_Family', ('female', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female',), 8),
#  ('7_Family', ('Survived', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('Survived', '3rd', 'male', 'S'), 1),
#  ('7_Family', ('Survived', '3rd', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('7_Family', ('Survived', '3rd', 'male'), 1),
#  ('7_Family', ('Survived', '3rd', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('7_Family', ('Survived', '3rd', 'S'), 4),
#  ('7_Family', ('Survived', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('7_Family', ('Survived', '3rd'), 4),
#  ('7_Family', ('Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('7_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('3rd', 'Not Survived', 'S'), 8),
#  ('7_Family', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('3rd', 'Not Survived'), 8),
#  ('7_Family', ('3rd', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('7_Family', ('3rd', 'S'), 12),
#  ('7_Family', ('3rd', '[0.0, 51.2)_Fare'), 12),
#  ('7_Family', ('3rd',), 12),
#  ('7_Family', ('Not Survived', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('[8.0, 16.0)_Age', 'female'), 2),
#  ('5_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('5_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', '3rd'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'S'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age',), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', 'female', 'S'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', 'female'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', 'male'), 1),
#  ('5_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', 'S'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age',), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', 'female'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', 'Survived'), 1),
#  ('5_Family',
#   ('[48.0, 56.0)_Age', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('5_Family', ('[48.0, 56.0)_Age', 'Not Survived', 'S'), 1),
#  ('5_Family', ('[48.0, 56.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 1),
#  ('5_Family', ('[48.0, 56.0)_Age', 'Not Survived'), 1),
#  ('5_Family', ('[48.0, 56.0)_Age', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', 'S'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age',), 2),
#  ('5_Family', ('C', '[16.0, 24.0)_Age', 'female'), 2),
#  ('5_Family', ('C', '[16.0, 24.0)_Age', 'Survived'), 2),
#  ('5_Family', ('C', '[16.0, 24.0)_Age'), 2),
#  ('5_Family', ('C', '1st', 'female', 'Survived'), 2),
#  ('5_Family', ('C', '1st', 'female'), 2),
#  ('5_Family', ('C', '1st', 'Survived'), 2),
#  ('5_Family', ('C', '1st'), 2),
#  ('5_Family', ('C', 'female', 'Survived'), 2),
#  ('5_Family', ('C', 'female'), 2),
#  ('5_Family', ('C', 'Survived'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st', 'female'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st', 'Survived'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'Survived'), 2),
#  ('5_Family',
#   ('[16.0, 24.0)_Age',
#    'female',
#    '3rd',
#    'Not Survived',
#    'S',
#    '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', 'S'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'S', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'S'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'S'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '[0.0, 51.2)_Fare'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female'), 6),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Survived'), 2),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived', 'S'), 5),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'S'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd'), 5),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Not Survived', 'S'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Not Survived'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'S'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age',), 7),
#  ('5_Family', ('1st', 'female', 'Survived'), 2),
#  ('5_Family', ('1st', 'female'), 2),
#  ('5_Family',
#   ('[24.0, 32.0)_Age', 'female', '3rd', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('5_Family', ('[24.0, 32.0)_Age', 'female', '3rd', 'S'), 1),
#  ('5_Family', ('[24.0, 32.0)_Age', 'female', '3rd', '[0.0, 51.2)_Fare'), 1),
#  ('5_Family', ('[24.0, 32.0)_Age', 'female', '3rd'), 1),
#  ('5_Family', ('[24.0, 32.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('5_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd', 'Not Survived', 'S'), 9),
#  ('5_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd', 'Not Survived'), 9),
#  ('5_Family', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd', 'S'), 9),
#  ('5_Family', ('female', '3rd', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd'), 9),
#  ('5_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', 'Not Survived', 'S'), 9),
#  ('5_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', 'Not Survived'), 9),
#  ('5_Family', ('female', 'S', '[0.0, 51.2)_Fare'), 10),
#  ('5_Family', ('female', 'S'), 10),
#  ('5_Family', ('female', '[0.0, 51.2)_Fare'), 10),
#  ('5_Family', ('female',), 12),
#  ('5_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd', 'Not Survived', 'S'), 12),
#  ('5_Family', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd', 'Not Survived'), 12),
#  ('5_Family', ('3rd', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd', 'S'), 12),
#  ('5_Family', ('3rd', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd',), 12),
#  ('5_Family', ('Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('Not Survived', 'S'), 12),
#  ('5_Family', ('Not Survived', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('Not Survived',), 12),
#  ('5_Family', ('S', '[0.0, 51.2)_Fare'), 13),
#  ('5_Family', ('S',), 13),
#  ('6_Family', ('[8.0, 16.0)_Age', 'female'), 1),
#  ('6_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('6_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', '3rd'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age', ('6_Family', 'Not Survived'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[8.0, 16.0)_Age', 'S'), 3),
#  ('[8.0, 16.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age', ('6_Family',), 4),
#  ('6_Family', ('[8.0, 16.0)_Age',), 4),
#  ('6_Family', ('[0.0, 8.0)_Age', 'female', 'S'), 1),
#  ('6_Family', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[0.0, 8.0)_Age', 'female'), 1),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 5),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd'), 8),
#  ('[0.0, 8.0)_Age', ('6_Family', 'Not Survived'), 8),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 4),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 7),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male'), 7),
#  ('6_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('[0.0, 8.0)_Age', 'S'), 5),
#  ('[0.0, 8.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 8),
#  ('[0.0, 8.0)_Age', ('6_Family',), 8),
#  ('6_Family', ('[0.0, 8.0)_Age',), 8),
#  ('6_Family', ('Q', 'female', '3rd', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('Q', 'female', '3rd'), 1),
#  ('6_Family', ('Q', 'female', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('Q', 'female'), 1),
#  ('6_Family', ('Q', '3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', '3rd', 'Not Survived', 'male'), 4),
#  ('6_Family', ('Q', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('Q', '3rd', 'Not Survived'), 5),
#  ('6_Family', ('Q', '3rd', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', '3rd', 'male'), 4),
#  ('6_Family', ('Q', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('Q', '3rd'), 5),
#  ('6_Family', ('Q', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', 'Not Survived', 'male'), 4),
#  ('6_Family', ('Q', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('Q', ('6_Family', 'Not Survived'), 5),
#  ('6_Family', ('Q', 'Not Survived'), 5),
#  ('6_Family', ('Q', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', 'male'), 4),
#  ('Q', ('6_Family', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('Q', '[0.0, 51.2)_Fare'), 5),
#  ('Q', ('6_Family',), 5),
#  ('6_Family', ('Q',), 5),
#  ('6_Family', ('[40.0, 48.0)_Age', 'female', 'S'), 2),
#  ('6_Family', ('[40.0, 48.0)_Age', 'female', '[0.0, 51.2)_Fare'), 2),
#  ('6_Family', ('[40.0, 48.0)_Age', 'female'), 2),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'male'), 1),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'S'), 3),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'male', 'S'), 1),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'male'), 1),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'S'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd'), 3),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('[40.0, 48.0)_Age', 'Not Survived', 'male', 'S'), 1),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   3),
#  ('6_Family', ('[40.0, 48.0)_Age', 'Not Survived', 'S'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 3),
#  ('[40.0, 48.0)_Age', ('6_Family', 'Not Survived'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', 'Not Survived'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[40.0, 48.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', 'S'), 3),
#  ('[40.0, 48.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '[0.0, 51.2)_Fare'), 3),
#  ('[40.0, 48.0)_Age', ('6_Family',), 3),
#  ('6_Family', ('[40.0, 48.0)_Age',), 3),
#  ('6_Family', ('[32.0, 40.0)_Age', 'female', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[32.0, 40.0)_Age', 'female'), 1),
#  ('6_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived'), 1),
#  ('6_Family', ('[32.0, 40.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[32.0, 40.0)_Age', '3rd'), 1),
#  ('[32.0, 40.0)_Age', ('6_Family', 'Not Survived'), 1),
#  ('[32.0, 40.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 1),
#  ('[32.0, 40.0)_Age', ('6_Family',), 1),
#  ('6_Family',
#   ('2nd', '[24.0, 32.0)_Age', 'female', 'Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('6_Family',
#   ('2nd', '[24.0, 32.0)_Age', 'female', 'Survived', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'female', 'Survived'), 1),
#  ('6_Family',
#   ('2nd', '[24.0, 32.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'female', 'S'), 1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'female', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'female'), 1),
#  ('6_Family',
#   ('2nd', '[24.0, 32.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'Survived', 'S'), 1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'Survived', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('2nd', '[24.0, 32.0)_Age', 'Survived'), 1),
#  ('2nd', ('6_Family', '[0.0, 51.2)_Fare'), 1),
#  ('2nd', ('6_Family',), 1),
#  ('6_Family', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 1),
#  ('6_Family', ('[16.0, 24.0)_Age', '1st', 'female'), 1),
#  ('6_Family', ('[16.0, 24.0)_Age', '1st', 'Survived'), 1),
#  ('6_Family', ('[16.0, 24.0)_Age', '1st'), 2),
#  ('6_Family', ('[16.0, 24.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('6_Family', ('[16.0, 24.0)_Age', 'Survived', 'S'), 1),
#  ('6_Family', ('[16.0, 24.0)_Age', 'Not Survived', 'male', 'S'), 2),
#  ('6_Family', ('[16.0, 24.0)_Age', 'Not Survived', 'male'), 2),
#  ('[16.0, 24.0)_Age', ('6_Family', 'Not Survived'), 2),
#  ('6_Family', ('[16.0, 24.0)_Age', 'male', 'S'), 2),
#  ('6_Family', ('[16.0, 24.0)_Age', 'S'), 3),
#  ('[16.0, 24.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 1),
#  ('[16.0, 24.0)_Age', ('6_Family',), 3),
#  ('6_Family', ('1st', '[24.0, 32.0)_Age', 'Survived'), 1),
#  ('6_Family', ('1st', '[24.0, 32.0)_Age'), 1),
#  ('6_Family', ('1st', 'female', 'Survived', 'S'), 2),
#  ('6_Family', ('1st', 'female', 'Survived'), 2),
#  ('6_Family', ('1st', 'female', 'S'), 2),
#  ('6_Family', ('1st', 'female'), 2),
#  ('6_Family', ('1st', 'Survived', 'S'), 2),
#  ('6_Family', ('1st', 'Not Survived', 'male', 'S'), 2),
#  ('6_Family', ('1st', 'Not Survived', 'male'), 2),
#  ('6_Family', ('1st', 'Not Survived', 'S'), 2),
#  ('1st', ('6_Family', 'Not Survived'), 2),
#  ('6_Family', ('1st', 'Not Survived'), 2),
#  ('6_Family', ('1st', 'male', 'S'), 2),
#  ('6_Family', ('1st', 'S'), 4),
#  ('1st', ('6_Family',), 4),
#  ('6_Family',
#   ('[24.0, 32.0)_Age', 'female', 'Survived', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 2),
#  ('6_Family',
#   ('[24.0, 32.0)_Age', 'female', 'Survived', '[0.0, 51.2)_Fare'),
#   1),
#  ('6_Family', ('[24.0, 32.0)_Age', 'female', 'Survived'), 2),
#  ('6_Family', ('[24.0, 32.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[24.0, 32.0)_Age', 'female', 'S'), 2),
#  ('6_Family', ('[24.0, 32.0)_Age', 'female'), 2),
#  ('6_Family', ('[24.0, 32.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('6_Family', ('[24.0, 32.0)_Age', 'Survived', 'S'), 2),
#  ('6_Family', ('[24.0, 32.0)_Age', 'Survived'), 2),
#  ('[24.0, 32.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 1),
#  ('[24.0, 32.0)_Age', ('6_Family',), 2),
#  ('6_Family', ('female', 'Survived', 'S'), 3),
#  ('6_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('female', '3rd', 'Not Survived', 'S'), 4),
#  ('6_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('female', '3rd', 'Not Survived'), 5),
#  ('6_Family', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('female', '3rd', 'S'), 4),
#  ('6_Family', ('female', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('female', '3rd'), 5),
#  ('6_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('female', 'Not Survived', 'S'), 4),
#  ('6_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('female', ('6_Family', 'Not Survived'), 5),
#  ('6_Family', ('female', 'Not Survived'), 5),
#  ('6_Family', ('female', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('female', 'S'), 7),
#  ('female', ('6_Family', '[0.0, 51.2)_Fare'), 6),
#  ('6_Family', ('female', '[0.0, 51.2)_Fare'), 6),
#  ('female', ('6_Family',), 8),
#  ('6_Family', ('female',), 8),
#  ('Survived', ('6_Family', '[0.0, 51.2)_Fare'), 1),
#  ('Survived', ('6_Family',), 3),
#  ('6_Family', ('3rd', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('3rd', 'Not Survived', 'male', 'S'), 8),
#  ('6_Family', ('3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'Not Survived', 'male'), 12),
#  ('6_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'Not Survived', 'S'), 12),
#  ('6_Family', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 17),
#  ('3rd', ('6_Family', 'Not Survived'), 17),
#  ('6_Family', ('3rd', 'Not Survived'), 17),
#  ('6_Family', ('3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('3rd', 'male', 'S'), 8),
#  ('6_Family', ('3rd', 'male', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'male'), 12),
#  ('6_Family', ('3rd', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'S'), 12),
#  ('3rd', ('6_Family', '[0.0, 51.2)_Fare'), 17),
#  ('6_Family', ('3rd', '[0.0, 51.2)_Fare'), 17),
#  ('3rd', ('6_Family',), 17),
#  ('6_Family', ('3rd',), 17),
#  ('6_Family', ('Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('Not Survived', 'male', 'S'), 10),
#  ('6_Family', ('Not Survived', 'male', '[0.0, 51.2)_Fare'), 12),
#  ('male', ('6_Family', 'Not Survived'), 14),
#  ('6_Family', ('Not Survived', 'male'), 14),
#  ('6_Family', ('Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('S', ('6_Family', 'Not Survived'), 14),
#  ('6_Family', ('Not Survived', 'S'), 14),
#  ('[0.0, 51.2)_Fare', ('6_Family', 'Not Survived'), 17),
#  ('Not Survived', ('6_Family', '[0.0, 51.2)_Fare'), 17),
#  ('6_Family', ('Not Survived', '[0.0, 51.2)_Fare'), 17),
#  ('Not Survived', ('6_Family',), 19),
#  ('6_Family', ('Not Survived',), 19),
#  ('6_Family', ('male', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('male', 'S'), 10),
#  ('male', ('6_Family', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('male', '[0.0, 51.2)_Fare'), 12),
#  ('male', ('6_Family',), 14),
#  ('6_Family', ('male',), 14),
#  ('S', ('6_Family', '[0.0, 51.2)_Fare'), 13),
#  ('6_Family', ('S', '[0.0, 51.2)_Fare'), 13),
#  ('S', ('6_Family',), 17),
#  ('6_Family', ('S',), 17),
#  ('[0.0, 51.2)_Fare', ('6_Family',), 18),
#  ...]

# %%
rules = apriori(baskets, supp=10, zmin=2, target='r', conf=60,
                report='ascl')

# %%
for r in rules:
    if r[0] == 'Survived':
        print(r)
# Out:
# ('Survived', ('[51.2, 102.4)_Fare',), 68, 0.07631874298540965, 0.6601941747572816, 1.719979560551865)
# ('Survived', ('[16.0, 24.0)_Age', 'female'), 68, 0.07631874298540965, 0.68, 1.7715789473684211)
# ('Survived', ('1st', 'female'), 91, 0.10213243546576879, 0.9680851063829787, 2.5221164613661813)
# ('Survived', ('1st',), 136, 0.1526374859708193, 0.6296296296296297, 1.6403508771929824)
# ('Survived', ('female', '1_Family', '[0.0, 51.2)_Fare'), 73, 0.0819304152637486, 0.73, 1.901842105263158)
# ('Survived', ('female', '1_Family'), 99, 0.1111111111111111, 0.7857142857142857, 2.0469924812030076)
# ('Survived', ('female', 'S', '[0.0, 51.2)_Fare'), 100, 0.1122334455667789, 0.6329113924050633, 1.6489007328447702)
# ('Survived', ('female', 'S'), 142, 0.15937149270482603, 0.6926829268292682, 1.8046213093709884)
# ('Survived', ('female', '[0.0, 51.2)_Fare'), 153, 0.1717171717171717, 0.6681222707423581, 1.7406343369340382)
# ('Survived', ('female',), 233, 0.2615039281705948, 0.7420382165605095, 1.9332048273550118)

# %%
for r in rules:
    if r[0] == 'Not Survived':
        print(r)
# Out:
# ('Not Survived', ('[40.0, 48.0)_Age',), 66, 0.07407407407407407, 0.6947368421052632, 1.127523727351165)
# ('Not Survived', ('[32.0, 40.0)_Age', '[0.0, 51.2)_Fare'), 64, 0.0718294051627385, 0.6881720430107527, 1.116869381279746)
# ('Not Survived', ('C', 'male'), 66, 0.07407407407407407, 0.6947368421052632, 1.127523727351165)
# ('Not Survived', ('2nd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 62, 0.06958473625140292, 0.6666666666666666, 1.0819672131147542)
# ('Not Survived', ('2nd', '1_Family', 'S'), 64, 0.0718294051627385, 0.6736842105263158, 1.0933563416738568)
# ('Not Survived', ('2nd', '1_Family', '[0.0, 51.2)_Fare'), 66, 0.07407407407407407, 0.6470588235294118, 1.0501446480231438)
# ('Not Survived', ('2nd', '1_Family'), 68, 0.07631874298540965, 0.6538461538461539, 1.0611601513240858)
# ('Not Survived', ('2nd', 'male', 'S', '[0.0, 51.2)_Fare'), 77, 0.08641975308641975, 0.8369565217391305, 1.3583392729864576)
# ('Not Survived', ('2nd', 'male', 'S'), 82, 0.0920314253647587, 0.845360824742268, 1.3719790434341728)
# ('Not Survived', ('2nd', 'male', '[0.0, 51.2)_Fare'), 86, 0.09652076318742986, 0.8349514563106796, 1.355085150405857)
# ('Not Survived', ('2nd', 'male'), 91, 0.10213243546576879, 0.8425925925925926, 1.3674863387978142)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 76, 0.08529741863075196, 0.6972477064220184, 1.131598736652128)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family'), 76, 0.08529741863075196, 0.6972477064220184, 1.131598736652128)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 84, 0.09427609427609428, 0.8316831683168316, 1.349780879727317)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'S'), 87, 0.09764309764309764, 0.8365384615384616, 1.3576607818411097)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 101, 0.11335578002244669, 0.6824324324324325, 1.1075542755870624)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd'), 104, 0.11672278338945005, 0.6887417218543046, 1.1177939420258387)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'S', '[0.0, 51.2)_Fare'), 76, 0.08529741863075196, 0.8260869565217391, 1.3406985032074128)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'S'), 78, 0.08754208754208755, 0.8041237113402062, 1.305053236437384)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 88, 0.09876543209876543, 0.6875, 1.1157786885245902)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family'), 91, 0.10213243546576879, 0.6791044776119403, 1.102153168583313)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male', 'S'), 86, 0.09652076318742986, 0.9347826086956522, 1.5171062009978618)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male', '[0.0, 51.2)_Fare'), 87, 0.09764309764309764, 0.90625, 1.4707991803278688)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male'), 95, 0.10662177328843996, 0.8962264150943396, 1.454531394989174)
# ('Not Survived', ('[16.0, 24.0)_Age', 'S', '[0.0, 51.2)_Fare'), 98, 0.10998877665544332, 0.7777777777777778, 1.2622950819672132)
# ('Not Survived', ('[16.0, 24.0)_Age', 'S'), 107, 0.12008978675645342, 0.7482517482517482, 1.21437578814628)
# ('Not Survived', ('[16.0, 24.0)_Age', '[0.0, 51.2)_Fare'), 116, 0.13019079685746351, 0.651685393258427, 1.0576533431571191)
# ('Not Survived', ('[16.0, 24.0)_Age',), 127, 0.1425364758698092, 0.616504854368932, 1.0005570587299062)
# ('Not Survived', ('1st', 'male'), 77, 0.08641975308641975, 0.6311475409836066, 1.0243214189733942)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 112, 0.12570145903479238, 0.8818897637795275, 1.4312637149864464)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'male'), 114, 0.12794612794612795, 0.8636363636363636, 1.401639344262295)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 78, 0.08754208754208755, 0.8387096774193549, 1.3611845584346907)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'S'), 80, 0.08978675645342311, 0.8163265306122449, 1.3248578119772498)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 118, 0.1324354657687991, 0.855072463768116, 1.3877405559515323)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family'), 120, 0.13468013468013468, 0.8391608391608392, 1.3619167717528373)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 89, 0.09988776655443322, 0.89, 1.4444262295081967)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male', 'S'), 95, 0.10662177328843996, 0.8715596330275229, 1.41449842081516)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 135, 0.15151515151515152, 0.8766233766233766, 1.4227166276346603)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male'), 141, 0.15824915824915825, 0.8650306748466258, 1.403902242783868)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 101, 0.11335578002244669, 0.8278688524590164, 1.3435904326793873)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'S'), 107, 0.12008978675645342, 0.816793893129771, 1.3256163183581529)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 148, 0.16610549943883277, 0.8268156424581006, 1.341881124645114)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd'), 154, 0.1728395061728395, 0.8191489361702128, 1.329438437391001)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 100, 0.1122334455667789, 0.8695652173913043, 1.4112615823235923)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male', 'S'), 102, 0.11447811447811448, 0.85, 1.3795081967213114)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 141, 0.15824915824915825, 0.8650306748466258, 1.403902242783868)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male'), 144, 0.16161616161616163, 0.8470588235294118, 1.37473481195757)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'S', '[0.0, 51.2)_Fare'), 106, 0.11896745230078563, 0.7910447761194029, 1.2838267678003425)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'S'), 108, 0.12121212121212122, 0.7552447552447552, 1.2257250945775535)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 148, 0.16610549943883277, 0.7914438502673797, 1.2844744455159114)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family'), 151, 0.16947250280583614, 0.7438423645320197, 1.2072195752240975)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 120, 0.13468013468013468, 0.8823529411764706, 1.4320154291224687)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male', 'S'), 129, 0.1447811447811448, 0.86, 1.3957377049180328)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male', '[0.0, 51.2)_Fare'), 172, 0.19304152637485972, 0.8686868686868687, 1.4098360655737705)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male'), 185, 0.20763187429854096, 0.8447488584474886, 1.3709858522344487)
# ('Not Survived', ('[24.0, 32.0)_Age', 'S', '[0.0, 51.2)_Fare'), 135, 0.15151515151515152, 0.75, 1.2172131147540983)
# ('Not Survived', ('[24.0, 32.0)_Age', 'S'), 145, 0.1627384960718294, 0.7178217821782178, 1.1649894497646487)
# ('Not Survived', ('[24.0, 32.0)_Age', '[0.0, 51.2)_Fare'), 188, 0.21099887766554434, 0.749003984063745, 1.215596629873947)
# ('Not Survived', ('[24.0, 32.0)_Age',), 202, 0.22671156004489337, 0.7062937062937062, 1.146279949558638)
# ('Not Survived', ('3rd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 175, 0.19640852974186307, 0.8974358974358975, 1.4564943253467844)
# ('Not Survived', ('3rd', '1_Family', 'male', 'S'), 177, 0.19865319865319866, 0.8762376237623762, 1.422090569712709)
# ('Not Survived', ('3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 230, 0.25813692480359146, 0.8949416342412452, 1.4524462588505453)
# ('Not Survived', ('3rd', '1_Family', 'male'), 232, 0.26038159371492703, 0.8787878787878788, 1.4262295081967213)
# ('Not Survived', ('3rd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 191, 0.2143658810325477, 0.8488888888888889, 1.377704918032787)
# ('Not Survived', ('3rd', '1_Family', 'S'), 193, 0.2166105499438833, 0.8318965517241379, 1.3501271905031091)
# ('Not Survived', ('3rd', '1_Family', '[0.0, 51.2)_Fare'), 253, 0.2839506172839506, 0.7981072555205048, 1.295288824533278)
# ('Not Survived', ('3rd', '1_Family'), 255, 0.28619528619528617, 0.7870370370370371, 1.2773224043715847)
# ('Not Survived', ('3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 225, 0.25252525252525254, 0.8858267716535433, 1.4376532851426358)
# ('Not Survived', ('3rd', 'male', 'S'), 231, 0.25925925925925924, 0.8716981132075472, 1.4147231673368388)
# ('Not Survived', ('3rd', 'male', '[0.0, 51.2)_Fare'), 294, 0.32996632996632996, 0.875, 1.4200819672131149)
# ('Not Survived', ('3rd', 'male'), 300, 0.3367003367003367, 0.8645533141210374, 1.4031275098029952)
# ('Not Survived', ('3rd', 'S', '[0.0, 51.2)_Fare'), 277, 0.3108866442199775, 0.8171091445427728, 1.3261279558972872)
# ('Not Survived', ('3rd', 'S'), 286, 0.32098765432098764, 0.8101983002832861, 1.3149119955417266)
# ('Not Survived', ('3rd', '[0.0, 51.2)_Fare'), 363, 0.4074074074074074, 0.7610062893081762, 1.2350757810083515)
# ('Not Survived', ('3rd',), 372, 0.4175084175084175, 0.7576374745417516, 1.229608360321859)
# ('Not Survived', ('1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 266, 0.29854096520763185, 0.86084142394822, 1.3971032946044883)
# ('Not Survived', ('1_Family', 'male', 'S'), 273, 0.3063973063973064, 0.8504672897196262, 1.380266584954803)
# ('Not Survived', ('1_Family', 'male', '[0.0, 51.2)_Fare'), 336, 0.3771043771043771, 0.8549618320610687, 1.3875610061318984)
# ('Not Survived', ('1_Family', 'male'), 347, 0.3894500561167228, 0.8442822384428224, 1.3702285509154002)
# ('Not Survived', ('1_Family', 'S', '[0.0, 51.2)_Fare'), 285, 0.31986531986531985, 0.7681940700808625, 1.2467411957050063)
# ('Not Survived', ('1_Family', 'S'), 292, 0.3277216610549944, 0.739240506329114, 1.1997509856816766)
# ('Not Survived', ('1_Family', '[0.0, 51.2)_Fare'), 363, 0.4074074074074074, 0.7363083164300203, 1.1949921856815082)
# ('Not Survived', ('1_Family',), 374, 0.41975308641975306, 0.6964618249534451, 1.130323289678542)
# ('Not Survived', ('male', 'S', '[0.0, 51.2)_Fare'), 334, 0.37485970819304154, 0.8455696202531645, 1.372317908279726)
# ('Not Survived', ('male', 'S'), 364, 0.40852974186307517, 0.8253968253968254, 1.3395784543325526)
# ('Not Survived', ('male', '[0.0, 51.2)_Fare'), 424, 0.47586980920314254, 0.8379446640316206, 1.359942979330007)
# ('Not Survived', ('male',), 468, 0.5252525252525253, 0.8110918544194108, 1.3163621899593716)
# ('Not Survived', ('S', '[0.0, 51.2)_Fare'), 392, 0.4399551066217733, 0.7088607594936709, 1.1504461506536625)
# ('Not Survived', ('S',), 427, 0.4792368125701459, 0.6609907120743034, 1.0727554179566563)
# ('Not Survived', ('[0.0, 51.2)_Fare',), 500, 0.5611672278338945, 0.6802721088435374, 1.1040481766477082)
